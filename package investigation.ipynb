# %%
import fastf1

fastf1.Cache.enable_cache('.\cache')
session = fastf1.get_session(2022, 7, "Q")
session.name
# Out:
# 'Qualifying'

# %%
session.date
# Out:
# Timestamp('2022-05-28 16:00:00')

# %%
session.event
# Out:
# RoundNumber                                            7
# Country                                           Monaco
# Location                                          Monaco
# OfficialEventName    FORMULA 1 GRAND PRIX DE MONACO 2022
# EventDate                            2022-05-29 17:00:00
# EventName                              Monaco Grand Prix
# EventFormat                                 conventional
# Session1                                      Practice 1
# Session1Date                         2022-05-27 14:00:00
# Session2                                      Practice 2
# Session2Date                         2022-05-27 17:00:00
# Session3                                      Practice 3
# Session3Date                         2022-05-28 13:00:00
# Session4                                      Qualifying
# Session4Date                         2022-05-28 16:00:00
# Session5                                            Race
# ...

# %%
event = fastf1.get_event(2021, 7)
event
# Out:
# RoundNumber                                                     7
# Country                                                    France
# Location                                             Le Castellet
# OfficialEventName    FORMULA 1 EMIRATES GRAND PRIX DE FRANCE 2021
# EventDate                                     2021-06-20 00:00:00
# EventName                                       French Grand Prix
# EventFormat                                          conventional
# Session1                                               Practice 1
# Session1Date                                  2021-06-18 00:00:00
# Session2                                               Practice 2
# Session2Date                                  2021-06-18 00:00:00
# Session3                                               Practice 3
# Session3Date                                  2021-06-19 00:00:00
# Session4                                               Qualifying
# ...

# %%
schedule = fastf1.get_event_schedule(2023)
schedule
# Out:
#     RoundNumber        Country           Location  \
# 0             0        Bahrain             Sakhir
# 1             1        Bahrain             Sakhir
# 2             2   Saudi Arabia             Jeddah
# 3             3      Australia          Melbourne
# 4             4     Azerbaijan               Baku
# 5             5  United States              Miami
# 6             6          Italy              Imola
# 7             7         Monaco             Monaco
# 8             8          Spain          Barcelona
# 9             9         Canada           Montréal
# 10           10        Austria          Spielberg
# 11           11  Great Britain        Silverstone
# 12           12        Hungary           Budapest
# 13           13        Belgium  Spa-Francorchamps
# 14           14    Netherlands          Zandvoort
# 15           15          Italy              Monza
# 16           16      Singapore         Marina Bay
# 17           17          Japan             Suzuka
# ...

# %%
session = fastf1.get_session(2021, 'French Grand Prix', 'Q')
session.load()
session.results
# Out:
# core           INFO 	Loading data for French Grand Prix - Qualifying [v2.3.0]
# api            INFO 	No cached data found for driver_info. Loading data...
# api            INFO 	Fetching driver list...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_data. Loading data...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api         WARNING 	Driver 55: Ignoring late data for a previously processed lap.The data may contain errors (previous: 17; current 18)
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_app_data. Loading data...
# api            INFO 	Fetching timing app data...
# api            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# api            INFO 	No cached data found for session_status_data. Loading data...
# api            INFO 	Fetching session status data...
# ...

# %%
fastf1.Cache.clear_cache("./cache")

# %%
session_gp1_r = fastf1.get_session(2022,1, "R")
session_gp1_r.load()
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v2.3.0]
# api            INFO 	No cached data found for driver_info. Loading data...
# api            INFO 	Fetching driver list...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_data. Loading data...
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for timing_app_data. Loading data...
# api            INFO 	Fetching timing app data...
# api            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# api            INFO 	No cached data found for session_status_data. Loading data...
# api            INFO 	Fetching session status data...
# api            INFO 	Data has been written to cache!
# api            INFO 	No cached data found for track_status_data. Loading data...
# ...

# %%
session_gp1_r.laps
# Out:
#                        Time DriverNumber                LapTime  LapNumber  \
# 0    0 days 01:04:14.256000           16                    NaT          1
# 1    0 days 01:05:52.109000           16 0 days 00:01:37.853000          2
# 2    0 days 01:07:30.381000           16 0 days 00:01:38.272000          3
# 3    0 days 01:09:08.795000           16 0 days 00:01:38.414000          4
# 4    0 days 01:10:47.266000           16 0 days 00:01:38.471000          5
# ...                     ...          ...                    ...        ...
# 1118 0 days 02:09:55.703000           10 0 days 00:01:38.204000         40
# 1119 0 days 02:11:34.004000           10 0 days 00:01:38.301000         41
# 1120 0 days 02:13:12.333000           10 0 days 00:01:38.329000         42
# 1121 0 days 02:14:50.811000           10 0 days 00:01:38.478000         43
# 1122 0 days 02:16:29.515000           10 0 days 00:01:38.704000         44
#
#                  PitOutTime PitInTime            Sector1Time  \
# ...

# %%
lec_lap_1 = session_gp1_r.laps.loc[2].get_telemetry()
# Out:
# C:\Users\gocal\Desktop\G-Boun\cmpe\lib\site-packages\fastf1\core.py:378: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data_slice.loc[:, 'Time'] = data_slice['SessionTime'] - start_time
# C:\Users\gocal\Desktop\G-Boun\cmpe\lib\site-packages\fastf1\core.py:378: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data_slice.loc[:, 'Time'] = data_slice['SessionTime'] - start_time
# ...

# %%
lec_lap_1.head()
# Out:
#                      Date            SessionTime DriverAhead  \
# 2 2022-03-20 15:06:52.126 0 days 01:05:52.109000
# 3 2022-03-20 15:06:52.188 0 days 01:05:52.171000
# 4 2022-03-20 15:06:52.301 0 days 01:05:52.284000
# 5 2022-03-20 15:06:52.588 0 days 01:05:52.571000
# 6 2022-03-20 15:06:52.601 0 days 01:05:52.584000
#
#    DistanceToDriverAhead                   Time    RPM  Speed  nGear  \
# 2                    NaN        0 days 00:00:00  11133    276      7
# 3                    NaN 0 days 00:00:00.062000  11151    277      7
# 4                    NaN 0 days 00:00:00.175000  11207    278      7
# 5                    NaN 0 days 00:00:00.462000  11264    280      7
# 6                    NaN 0 days 00:00:00.475000  11295    281      7
#
#    Throttle  Brake  DRS         Source   Distance  RelativeDistance   Status  \
# 2       100  False    1  interpolation   0.025341          0.000005  OnTrack
# 3       100  False    1            car   4.808889          0.000897  OnTrack
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.scatterplot(lec_lap_1, x = "SessionTime", y = "Speed", hue="Brake")
plt.show()

# %%
sns.scatterplot(lec_lap_1, x = "X", y = "Y", hue="Brake")
plt.show()
